# %%
import albumentations as A
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread('/disks/hdd/pku-autonomous-driving/train_images/ID_983c1e248.jpg')[:, :, ::-1]

# %%
plt.figure(figsize=[15, 10])
plt.imshow(img)

# %%
a = A.GaussNoise(var_limit=(50, 50), always_apply=True)

# %%
img_aug = a(image=img)['image']

# %%
plt.figure(figsize=[15, 10])
plt.imshow(img_aug)
